# %%
import warnings

# Ignore a specific warning by message (For Jupyter Notebook only)
warnings.filterwarnings('ignore')

from cifkit import Cif
import json

# Utility function for printing dictionary
def prettify_dict(dict_data):
  return json.dumps(dict_data, indent=4)

# Initialize
cif = Cif("/Users/macbook/Downloads/cifkit/tests/data/cif/ensemble_test/300169.cif")
cif.plot_polyhedron("Ge1", is_displayed=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1200>
